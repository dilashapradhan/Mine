# %% [markdown]
# <a href="https://colab.research.google.com/github/dilashapradhan/Mine/blob/master/Workshop6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Understanding and Visualizations.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Import Required Libraries

# %%
# Import required libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from PIL import Image, UnidentifiedImageError
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns

# Ensure reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Check TensorFlow version
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.18.0

# %% [markdown]
# ## 2. Dataset Preparation

# %% [markdown]
# ### 2.1 Verify Dataset Structure

# %%
# Define paths and parameters
train_dir = "/content/drive/MyDrive/AI/FruitinAmazon/FruitinAmazon/train"
test_dir = "/content/drive/MyDrive/AI/FruitinAmazon/FruitinAmazon/test"

img_size = (224, 224)
batch_size = 32

# Get class names
class_names = sorted(os.listdir(train_dir))
if not class_names:
    print("No class directories found in the train folder!")
else:
    print(f"Found {len(class_names)} classes: {class_names}")
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ### 2.2 Check for Corrupted Images

# %%
from PIL import Image, UnidentifiedImageError

corrupted_images = []  # List to store corrupted image paths

# Loop through each class folder and check for corrupted images
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):  # Ensure it’s a valid directory
        images = os.listdir(class_path)
        for img_name in images:
            img_path = os.path.join(class_path, img_name)
            try:
                with Image.open(img_path) as img:
                    img.verify()  # Verify image integrity
            except (IOError, UnidentifiedImageError):
                corrupted_images.append(img_path)

# Print results
if corrupted_images:
    print("\nCorrupted Images Found:")
    for img in corrupted_images:
        print(img)
else:
    print("\nNo corrupted images found.")
# Out:
# No corrupted images found.

# %% [markdown]
# ### 2.3 Count Class Balance

# %%
# Dictionary to store class counts
class_counts = {}

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        class_counts[class_name] = len(images)  # Count images in each class

# Print class balance
print("\nClass Distribution:")
print("=" * 45)
print(f"{'Class Name':<25}{'Valid Image Count':>15}")
print("=" * 45)
for class_name, count in class_counts.items():
    print(f"{class_name:<25}{count:>15}")
print("=" * 45)
# Out:
# Class Distribution:
# =============================================
# Class Name               Valid Image Count
# =============================================
# acai                                  15
# cupuacu                               15
# graviola                              15
# guarana                               15
# pupunha                               15
# tucuma                                15
# =============================================

# %% [markdown]
# ### 2.4 Select Random Images for Visualization

# %%
import random

selected_images = []  # Store image paths
selected_labels = []  # Store corresponding class names

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        if images:  # Ensure the class folder is not empty
            selected_img = os.path.join(class_path, random.choice(images))
            selected_images.append(selected_img)
            selected_labels.append(class_name)

# Display randomly selected images in a grid format
num_classes = len(selected_images)
cols = (num_classes + 1) // 2  # Determine columns
rows = 2  # Fixed rows for layout

fig, axes = plt.subplots(rows, cols, figsize=(12, 6))
for i, ax in enumerate(axes.flat):
    if i < num_classes:
        img = plt.imread(selected_images[i])
        ax.imshow(img)
        ax.set_title(selected_labels[i])
        ax.axis("off")
    else:
        ax.axis("off")  # Hide empty subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Generation and Preprocessing

# %% [markdown]
# ### 3.1 Generate Train and Validation Datasets

# %%
# Load datasets
train_ds = image_dataset_from_directory(
    train_dir,
    seed=1337,
    image_size=img_size,
    batch_size=batch_size,
)

test_ds = image_dataset_from_directory(
    test_dir,
    seed=1337,
    image_size=img_size,
    batch_size=batch_size,
)

# Prefetch datasets for better performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.

# %%
# Checking the shape of a batch
for images, labels in train_ds.take(1): # Take one batch
  print("Images shape:", images.shape)
  print("Labels shape:", labels.shape)
# Out:
# Images shape: (32, 224, 224, 3)
# Labels shape: (32,)

# %% [markdown]
# ### 3.2 Visualize Training Dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()

# %% [markdown]
# ### 3.3 Data Augmentation

# %%
# Define the data augmentation layers
data_augmentation = Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(0.2, 0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
])

# %% [markdown]
# ### Visualize augmented images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):  # Take 1 batch from original dataset
    augmented_images = data_augmentation(images)  # Apply augmentations
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.axis("off")
    break
plt.show()

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
# ### 4.1 Define the CNN Model

# %%
from tensorflow.keras.layers import (Lambda, Rescaling, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, Dense, Input, GlobalAveragePooling2D)

# Define the model using the Sequential API with a list of layers
model = Sequential([
    # Define the input shape using InputLayer
    Input(shape=(224, 224, 3)),

    # Data Augmentation using Lambda
    Lambda(data_augmentation, input_shape=(224, 224, 3)),

    # Rescaling layer
    Rescaling(1./255),

    # First Convolutional Block
    Conv2D(32, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Second Convolutional Block
    Conv2D(64, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Third Convolutional Block
    Conv2D(128, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Fourth Convolutional Block
    Conv2D(256, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Flatten before fully connected layers
    Flatten(),

    # Fully Connected Layer 1
    Dense(512, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 2
    Dense(256, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 3
    Dense(128, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 4
    Dense(64, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output layer (10 classes)
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                 │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    25,690,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,257,930 (100.17 MB)
#  Trainable params: 26,255,050 (100.16 MB)
#  Non-trainable params: 2,880 (11.25 KB)

# %% [markdown]
# ## 5. Training the Model

# %% [markdown]
# ### 5.1 Add Callbacks

# %%
# Define Early Stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',          # Monitor validation loss
    patience=10,                 # Wait for 10 epochs before stopping
    restore_best_weights=True   # Restore weights from the best epoch
)

# Define Learning Rate Reduction on Plateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',          # Monitor validation loss
    factor=0.5,                  # Reduce learning rate by a factor of 0.5
    patience=3,                  # Wait for 3 epochs before reducing LR
    min_lr=1e-6                  # Minimum learning rate
)

# %% [markdown]
# ## 5.2 Train the Model

# %%
# Train the model
history = model.fit(
    train_ds,
    validation_data=test_ds,     # Use test_ds for validation
    epochs=100,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 34s 11s/step - accuracy: 0.1119 - loss: 3.0081 - val_accuracy: 0.0000e+00 - val_loss: 2.3879 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 326ms/step - accuracy: 0.0701 - loss: 2.8402 - val_accuracy: 0.0667 - val_loss: 2.3183 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.1074 - loss: 2.9289 - val_accuracy: 0.2000 - val_loss: 2.3219 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.1464 - loss: 2.6374 - val_accuracy: 0.1667 - val_loss: 2.3030 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 0.0773 - loss: 2.8177 - val_accuracy: 0.1667 - val_loss: 2.2947 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.0829 - loss: 2.8842 - val_accuracy: 0.1667 - val_loss: 2.3008 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.1569 - loss: 2.6477 - val_accuracy: 0.1667 - val_loss: 2.3105 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.1843 - loss: 2.6118 - val_accuracy: 0.1333 - val_loss: 2.3297 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - accuracy: 0.2501 - loss: 2.2860 - val_accuracy: 0.1000 - val_loss: 2.3615 - learning_rate: 5.0000e-04
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.1682 - loss: 2.5521 - val_accuracy: 0.1000 - val_loss: 2.3885 - learning_rate: 5.0000e-04
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.1536 - loss: 2.5067 - val_accuracy: 0.1667 - val_loss: 2.4059 - learning_rate: 5.0000e-04
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.1699 - loss: 2.5102 - val_accuracy: 0.1667 - val_loss: 2.4165 - learning_rate: 2.5000e-04
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.2339 - loss: 2.4267 - val_accuracy: 0.1667 - val_loss: 2.4164 - learning_rate: 2.5000e-04
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.2077 - loss: 2.2551 - val_accuracy: 0.1667 - val_loss: 2.4062 - learning_rate: 2.5000e-04
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.2188 - loss: 2.3290 - val_accuracy: 0.1667 - val_loss: 2.3970 - learning_rate: 1.2500e-04

# %% [markdown]
# ## 6. Evaluate the Model

# %% [markdown]
# ## 6.1 Plot Training History

# %%
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Using Keras ImageDataGenerator (Old API)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    zoom_range=0.3,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load Data
train_data = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_data = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=False)

# Load Pretrained Model (MobileNetV2)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze initial layers

# Define Model
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(train_data.class_indices), activation='softmax')
])

# Compile Model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

# Train Model
history = model.fit(train_data, validation_data=test_data, epochs=70, callbacks=[early_stopping, lr_scheduler])

# Save the trained model
model.save("fruit_classification_model_v2.h5")

# Load the saved model
loaded_model = tf.keras.models.load_model("fruit_classification_model_v2.h5")

# Re-evaluate the model
y_true = test_data.classes
y_pred = np.argmax(loaded_model.predict(test_data), axis=1)
class_labels = list(test_data.class_indices.keys())

print("Re-evaluated Model Performance:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Plot Training Performance
plt.figure(figsize=(12,4))

# Accuracy Plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curve")

# Loss Plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curve")

plt.show()
# Out:
# Found 90 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 24s 6s/step - accuracy: 0.1105 - loss: 3.6735 - val_accuracy: 0.2000 - val_loss: 2.2088 - learning_rate: 1.0000e-04
# Epoch 2/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.1888 - loss: 2.9727 - val_accuracy: 0.3333 - val_loss: 2.0738 - learning_rate: 1.0000e-04
# Epoch 3/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 585ms/step - accuracy: 0.3235 - loss: 2.8490 - val_accuracy: 0.3667 - val_loss: 1.9490 - learning_rate: 1.0000e-04
# Epoch 4/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 588ms/step - accuracy: 0.3211 - loss: 2.7481 - val_accuracy: 0.4000 - val_loss: 1.8372 - learning_rate: 1.0000e-04
# Epoch 5/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 607ms/step - accuracy: 0.4009 - loss: 2.2796 - val_accuracy: 0.4667 - val_loss: 1.7390 - learning_rate: 1.0000e-04
# Epoch 6/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 906ms/step - accuracy: 0.3873 - loss: 2.2930 - val_accuracy: 0.4667 - val_loss: 1.6464 - learning_rate: 1.0000e-04
# Epoch 7/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 708ms/step - accuracy: 0.5000 - loss: 1.9497 - val_accuracy: 0.5333 - val_loss: 1.5641 - learning_rate: 1.0000e-04
# Epoch 8/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 623ms/step - accuracy: 0.4906 - loss: 1.8806 - val_accuracy: 0.6667 - val_loss: 1.4885 - learning_rate: 1.0000e-04
# Epoch 9/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 669ms/step - accuracy: 0.4861 - loss: 1.8460 - val_accuracy: 0.7333 - val_loss: 1.4181 - learning_rate: 1.0000e-04
# Epoch 10/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 588ms/step - accuracy: 0.5455 - loss: 1.6331 - val_accuracy: 0.7333 - val_loss: 1.3580 - learning_rate: 1.0000e-04
# Epoch 11/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 575ms/step - accuracy: 0.6247 - loss: 1.5010 - val_accuracy: 0.7667 - val_loss: 1.3063 - learning_rate: 1.0000e-04
# Epoch 12/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 737ms/step - accuracy: 0.7039 - loss: 1.3160 - val_accuracy: 0.7667 - val_loss: 1.2624 - learning_rate: 1.0000e-04
# Epoch 13/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 723ms/step - accuracy: 0.6732 - loss: 1.2028 - val_accuracy: 0.7667 - val_loss: 1.2242 - learning_rate: 1.0000e-04
# Epoch 14/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 599ms/step - accuracy: 0.7317 - loss: 1.2329 - val_accuracy: 0.7667 - val_loss: 1.1894 - learning_rate: 1.0000e-04
# Epoch 15/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 584ms/step - accuracy: 0.6481 - loss: 1.3865 - val_accuracy: 0.8000 - val_loss: 1.1561 - learning_rate: 1.0000e-04
# Epoch 16/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 641ms/step - accuracy: 0.7230 - loss: 1.2772 - val_accuracy: 0.8667 - val_loss: 1.1256 - learning_rate: 1.0000e-04
# Epoch 17/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.8052 - loss: 1.0851 - val_accuracy: 0.8667 - val_loss: 1.0967 - learning_rate: 1.0000e-04
# Epoch 18/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step - accuracy: 0.7332 - loss: 1.1020 - val_accuracy: 0.8667 - val_loss: 1.0701 - learning_rate: 1.0000e-04
# Epoch 19/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 926ms/step - accuracy: 0.7671 - loss: 1.0832 - val_accuracy: 0.8667 - val_loss: 1.0446 - learning_rate: 1.0000e-04
# Epoch 20/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 569ms/step - accuracy: 0.8385 - loss: 1.0022 - val_accuracy: 0.8667 - val_loss: 1.0215 - learning_rate: 1.0000e-04
# Epoch 21/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 625ms/step - accuracy: 0.7684 - loss: 1.0059 - val_accuracy: 0.8667 - val_loss: 1.0013 - learning_rate: 1.0000e-04
# Epoch 22/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 624ms/step - accuracy: 0.7182 - loss: 1.0656 - val_accuracy: 0.8667 - val_loss: 0.9802 - learning_rate: 1.0000e-04
# Epoch 23/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 583ms/step - accuracy: 0.8565 - loss: 0.8890 - val_accuracy: 0.8667 - val_loss: 0.9621 - learning_rate: 1.0000e-04
# Epoch 24/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 688ms/step - accuracy: 0.8402 - loss: 0.8878 - val_accuracy: 0.9000 - val_loss: 0.9454 - learning_rate: 1.0000e-04
# Epoch 25/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 796ms/step - accuracy: 0.8784 - loss: 0.8586 - val_accuracy: 0.9000 - val_loss: 0.9292 - learning_rate: 1.0000e-04
# Epoch 26/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 615ms/step - accuracy: 0.8073 - loss: 1.0903 - val_accuracy: 0.9000 - val_loss: 0.9129 - learning_rate: 1.0000e-04
# Epoch 27/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 575ms/step - accuracy: 0.8620 - loss: 0.8124 - val_accuracy: 0.9000 - val_loss: 0.8981 - learning_rate: 1.0000e-04
# Epoch 28/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.8620 - loss: 0.8377 - val_accuracy: 0.9000 - val_loss: 0.8857 - learning_rate: 1.0000e-04
# Epoch 29/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 636ms/step - accuracy: 0.9109 - loss: 0.7533 - val_accuracy: 0.9000 - val_loss: 0.8737 - learning_rate: 1.0000e-04
# Epoch 30/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 607ms/step - accuracy: 0.8604 - loss: 0.7749 - val_accuracy: 0.9000 - val_loss: 0.8640 - learning_rate: 1.0000e-04
# Epoch 31/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 857ms/step - accuracy: 0.8619 - loss: 0.7884 - val_accuracy: 0.9000 - val_loss: 0.8541 - learning_rate: 1.0000e-04
# Epoch 32/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 687ms/step - accuracy: 0.8585 - loss: 0.8104 - val_accuracy: 0.9000 - val_loss: 0.8466 - learning_rate: 1.0000e-04
# Epoch 33/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 568ms/step - accuracy: 0.8836 - loss: 0.7947 - val_accuracy: 0.9000 - val_loss: 0.8393 - learning_rate: 1.0000e-04
# Epoch 34/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 588ms/step - accuracy: 0.9087 - loss: 0.7571 - val_accuracy: 0.9000 - val_loss: 0.8309 - learning_rate: 1.0000e-04
# Epoch 35/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 592ms/step - accuracy: 0.9371 - loss: 0.6625 - val_accuracy: 0.9000 - val_loss: 0.8235 - learning_rate: 1.0000e-04
# Epoch 36/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step - accuracy: 0.9270 - loss: 0.6655 - val_accuracy: 0.9000 - val_loss: 0.8170 - learning_rate: 1.0000e-04
# Epoch 37/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 700ms/step - accuracy: 0.9206 - loss: 0.7064 - val_accuracy: 0.9333 - val_loss: 0.8093 - learning_rate: 1.0000e-04
# Epoch 38/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 978ms/step - accuracy: 0.8844 - loss: 0.7137 - val_accuracy: 0.9333 - val_loss: 0.8024 - learning_rate: 1.0000e-04
# Epoch 39/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 585ms/step - accuracy: 0.9394 - loss: 0.6745 - val_accuracy: 0.9333 - val_loss: 0.7937 - learning_rate: 1.0000e-04
# Epoch 40/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 656ms/step - accuracy: 0.8867 - loss: 0.9797 - val_accuracy: 0.9333 - val_loss: 0.7863 - learning_rate: 1.0000e-04
# Epoch 41/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 574ms/step - accuracy: 0.9181 - loss: 0.7041 - val_accuracy: 0.9333 - val_loss: 0.7803 - learning_rate: 1.0000e-04
# Epoch 42/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 591ms/step - accuracy: 0.8906 - loss: 0.7710 - val_accuracy: 0.9333 - val_loss: 0.7735 - learning_rate: 1.0000e-04
# Epoch 43/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 569ms/step - accuracy: 0.9488 - loss: 0.6418 - val_accuracy: 0.9333 - val_loss: 0.7669 - learning_rate: 1.0000e-04
# Epoch 44/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 712ms/step - accuracy: 0.8659 - loss: 0.7383 - val_accuracy: 0.9333 - val_loss: 0.7586 - learning_rate: 1.0000e-04
# Epoch 45/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 986ms/step - accuracy: 0.9846 - loss: 0.6075 - val_accuracy: 0.9333 - val_loss: 0.7504 - learning_rate: 1.0000e-04
# Epoch 46/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 630ms/step - accuracy: 0.9537 - loss: 0.5659 - val_accuracy: 0.9333 - val_loss: 0.7429 - learning_rate: 1.0000e-04
# Epoch 47/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 643ms/step - accuracy: 0.9441 - loss: 0.5947 - val_accuracy: 0.9333 - val_loss: 0.7367 - learning_rate: 1.0000e-04
# Epoch 48/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 578ms/step - accuracy: 0.8843 - loss: 0.7619 - val_accuracy: 0.9333 - val_loss: 0.7304 - learning_rate: 1.0000e-04
# Epoch 49/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 587ms/step - accuracy: 0.9064 - loss: 0.7575 - val_accuracy: 0.9333 - val_loss: 0.7241 - learning_rate: 1.0000e-04
# Epoch 50/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 572ms/step - accuracy: 0.9373 - loss: 0.5970 - val_accuracy: 0.9333 - val_loss: 0.7196 - learning_rate: 1.0000e-04
# Epoch 51/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 595ms/step - accuracy: 0.9070 - loss: 0.6306 - val_accuracy: 0.9333 - val_loss: 0.7163 - learning_rate: 1.0000e-04
# Epoch 52/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 735ms/step - accuracy: 0.9182 - loss: 0.7039 - val_accuracy: 0.9333 - val_loss: 0.7139 - learning_rate: 1.0000e-04
# Epoch 53/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 625ms/step - accuracy: 0.9034 - loss: 0.6979 - val_accuracy: 0.9333 - val_loss: 0.7115 - learning_rate: 1.0000e-04
# Epoch 54/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9439 - loss: 0.6060 - val_accuracy: 0.9333 - val_loss: 0.7093 - learning_rate: 1.0000e-04
# Epoch 55/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 653ms/step - accuracy: 0.9456 - loss: 0.6192 - val_accuracy: 0.9333 - val_loss: 0.7054 - learning_rate: 1.0000e-04
# Epoch 56/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 582ms/step - accuracy: 0.9488 - loss: 0.6297 - val_accuracy: 0.9333 - val_loss: 0.7012 - learning_rate: 1.0000e-04
# Epoch 57/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 638ms/step - accuracy: 0.8955 - loss: 0.6486 - val_accuracy: 0.9333 - val_loss: 0.6974 - learning_rate: 1.0000e-04
# Epoch 58/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 852ms/step - accuracy: 0.9343 - loss: 0.6487 - val_accuracy: 0.9333 - val_loss: 0.6946 - learning_rate: 1.0000e-04
# Epoch 59/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 729ms/step - accuracy: 0.9790 - loss: 0.5500 - val_accuracy: 0.9333 - val_loss: 0.6919 - learning_rate: 1.0000e-04
# Epoch 60/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 635ms/step - accuracy: 0.9302 - loss: 0.6027 - val_accuracy: 0.9333 - val_loss: 0.6895 - learning_rate: 1.0000e-04
# Epoch 61/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 653ms/step - accuracy: 0.9827 - loss: 0.5623 - val_accuracy: 0.9333 - val_loss: 0.6873 - learning_rate: 1.0000e-04
# Epoch 62/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 641ms/step - accuracy: 0.9276 - loss: 0.6009 - val_accuracy: 0.9333 - val_loss: 0.6847 - learning_rate: 1.0000e-04
# Epoch 63/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 635ms/step - accuracy: 0.9343 - loss: 0.6191 - val_accuracy: 0.9333 - val_loss: 0.6802 - learning_rate: 1.0000e-04
# Epoch 64/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 627ms/step - accuracy: 0.9401 - loss: 0.6114 - val_accuracy: 0.9333 - val_loss: 0.6772 - learning_rate: 1.0000e-04
# Epoch 65/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 906ms/step - accuracy: 0.9449 - loss: 0.6079 - val_accuracy: 0.9333 - val_loss: 0.6753 - learning_rate: 1.0000e-04
# Epoch 66/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - accuracy: 0.9735 - loss: 0.5602 - val_accuracy: 0.9333 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 67/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 591ms/step - accuracy: 0.9582 - loss: 0.5448 - val_accuracy: 0.9333 - val_loss: 0.6720 - learning_rate: 1.0000e-04
# Epoch 68/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 591ms/step - accuracy: 0.9669 - loss: 0.5840 - val_accuracy: 0.9333 - val_loss: 0.6699 - learning_rate: 1.0000e-04
# Epoch 69/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 616ms/step - accuracy: 0.8634 - loss: 0.7632 - val_accuracy: 0.9333 - val_loss: 0.6666 - learning_rate: 1.0000e-04
# Epoch 70/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 572ms/step - accuracy: 0.9833 - loss: 0.4963 - val_accuracy: 0.9333 - val_loss: 0.6639 - learning_rate: 1.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Re-evaluated Model Performance:
#               precision    recall  f1-score   support
#
#         acai       1.00      0.80      0.89         5
#      cupuacu       1.00      0.80      0.89         5
#     graviola       0.83      1.00      0.91         5
#      guarana       1.00      1.00      1.00         5
#      pupunha       1.00      1.00      1.00         5
#       tucuma       0.83      1.00      0.91         5
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.93      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# # Task 2: Transfer Learning with MobileNetV2

# %%
# Set image size compatible with MobileNetV2
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32

# Prepare ImageDataGenerators
train_ds = ImageDataGenerator(rescale=1./255)
val_ds = ImageDataGenerator(rescale=1./255)

# %%
train_gen = train_ds.flow_from_directory(
    '/content/drive/MyDrive/AI/FruitinAmazon/FruitinAmazon/train',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_gen = val_ds.flow_from_directory(
    '/content/drive/MyDrive/AI/FruitinAmazon/FruitinAmazon/test',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 90 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.

# %% [markdown]
# ## 1. Load the base model

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze all layers in the base model
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# ## 2. Add custom layers on top

# %%
from tensorflow.keras.models import Model

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(train_gen.num_classes, activation='softmax')(x)

# Final model
model_tl = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model_tl.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 3. Train the model

# %%
history_tl = model_tl.fit(
    train_gen,
    validation_data=val_gen,
    epochs=5
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.1324 - loss: 2.6190 - val_accuracy: 0.4000 - val_loss: 1.6044
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4220 - loss: 1.5464 - val_accuracy: 0.6667 - val_loss: 1.1491
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.6499 - loss: 1.0341 - val_accuracy: 0.7000 - val_loss: 0.7786
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.7650 - loss: 0.5818 - val_accuracy: 0.8000 - val_loss: 0.6274
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.9515 - loss: 0.3182 - val_accuracy: 0.8667 - val_loss: 0.5509

# %% [markdown]
# ## 4. Evaluate model performance

# %%
val_loss_tl, val_acc_tl = model_tl.evaluate(val_gen)
print(f"Validation Accuracy: {val_acc_tl:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8667 - loss: 0.5509
# Validation Accuracy: 0.8667

# %% [markdown]
# ## 5. Generate predictions and classification report

# %%
y_true = val_gen.classes
y_pred_probs = model_tl.predict(val_gen)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification Report
class_labels = list(val_gen.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=class_labels)
print("\nClassification Report:\n")
print(report)

# Inference output (show first 10 predictions)
print("\nSample Inference Results:")
for i in range(10):
    print(f"True: {class_labels[y_true[i]]}, Predicted: {class_labels[y_pred[i]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         acai       1.00      0.60      0.75         5
#      cupuacu       0.83      1.00      0.91         5
#     graviola       1.00      1.00      1.00         5
#      guarana       0.71      1.00      0.83         5
#      pupunha       0.80      0.80      0.80         5
#       tucuma       1.00      0.80      0.89         5
#
#     accuracy                           0.87        30
#    macro avg       0.89      0.87      0.86        30
# weighted avg       0.89      0.87      0.86        30
#
#
# Sample Inference Results:
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: acai, Predicted: pupunha
# True: acai, Predicted: cupuacu
# True: acai, Predicted: acai
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
